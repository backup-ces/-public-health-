# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/backup-ces/-public-health-/main/sample.csv"

# %%
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (1230, 57)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'COD_DPTO', 'COD_MUNIC', 'A_DEFUN', 'SIT_DEFUN',
#        'OTRSITIODE', 'TIPO_DEFUN', 'ANO', 'MES', 'HORA', 'MINUTOS', 'SEXO',
#        'EST_CIVIL', 'GRU_ED1', 'GRU_ED2', 'NIVEL_EDU', 'ULTCURFAL',
#        'MUERTEPORO', 'SIMUERTEPO', 'OCUPACION', 'IDPERTET', 'CODPRES',
#        'CODPTORE', 'CODMUNRE', 'AREA_RES', 'SEG_SOCIAL', 'IDADMISALUD',
#        'P_PMAN_IRIS', 'CONS_EXP', 'MU_PARTO', 'T_PARTO', 'TIPO_EMB', 'T_GES',
#        'T_GES_AGRU_CIE', 'PESO_NAC', 'EDAD_MADRE', 'N_HIJOSV', 'N_HIJOSM',
#        'EST_CIVM', 'NIV_EDUM', 'ULTCURMAD', 'EMB_FAL', 'EMB_SEM', 'EMB_MES',
#        'CODOCUR', 'CODMUNOC', 'C_MUERTE', 'C_MUERTEB', 'C_MUERTEC',
#        'C_MUERTED', 'C_MUERTEE', 'ASIS_MED', 'CAUSA_MULT', 'C_BAS1',
#        'CAUSA_667', 'IDPROFCER', 'CAU_HOMOL'],
#       dtype='object')

# %%
df['NIVEL_EDU'].value_counts()
# Out:
# 2     457
# 99    261
# 13    147
# 3     127
# 4     103
# 9      52
# 1      24
# 7      22
# 8      14
# 5      10
# 11      4
# 10      4
# 6       3
# 12      2
# Name: NIVEL_EDU, dtype: int64
